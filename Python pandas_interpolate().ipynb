# %% [markdown]
# # Pandas interpolate()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv')
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        NaN             8
# 2   3/7/2019         NaN     10        3.0             8
# 3   6/7/2019         NaN     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019         NaN     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        NaN             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df.interpolate()
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(method = 'linear')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv', parse_dates = ['Date'])
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0 2019-01-07      1001.0     10        2.0             9
# 1 2019-02-07      1002.0     10        NaN             8
# 2 2019-03-07         NaN     10        3.0             8
# 3 2019-06-07         NaN     11        0.0            10
# 4 2019-07-07      1005.0     11        4.0             7
# 5 2019-08-07         NaN     11       10.0             7
# 6 2019-09-07      1007.0     12        4.0             6
# 7 2019-10-07      1008.0     12        NaN             6
# 8 2019-11-07      1009.0     12        2.0             8
# 9 2019-12-07      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv', parse_dates = ['Date'], index_col = 'Date')
df
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07      1001.0     10        2.0             9
# 2019-02-07      1002.0     10        NaN             8
# 2019-03-07         NaN     10        3.0             8
# 2019-06-07         NaN     11        0.0            10
# 2019-07-07      1005.0     11        4.0             7
# 2019-08-07         NaN     11       10.0             7
# 2019-09-07      1007.0     12        4.0             6
# 2019-10-07      1008.0     12        NaN             6
# 2019-11-07      1009.0     12        2.0             8
# 2019-12-07      1010.0     12        6.0             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5        50.0       A
# 2019-02-07                       2                 0        80.0     NaN
# 2019-03-07                       2                 4        60.0     NaN
# ...

# %%
df.interpolate(method = 'time')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07     1001.00     10   2.000000             9
# 2019-02-07     1002.00     10   2.525424             8
# 2019-03-07     1002.56     10   3.000000             8
# 2019-06-07     1004.40     11   0.000000            10
# 2019-07-07     1005.00     11   4.000000             7
# 2019-08-07     1006.00     11  10.000000             7
# 2019-09-07     1007.00     12   4.000000             6
# 2019-10-07     1008.00     12   3.016393             6
# 2019-11-07     1009.00     12   2.000000             8
# 2019-12-07     1010.00     12   6.000000             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5   50.000000       A
# 2019-02-07                       2                 0   80.000000     NaN
# 2019-03-07                       2                 4   60.000000     NaN
# ...

# %%
df.interpolate(method = 'index')
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07     1001.00     10   2.000000             9
# 2019-02-07     1002.00     10   2.525424             8
# 2019-03-07     1002.56     10   3.000000             8
# 2019-06-07     1004.40     11   0.000000            10
# 2019-07-07     1005.00     11   4.000000             7
# 2019-08-07     1006.00     11  10.000000             7
# 2019-09-07     1007.00     12   4.000000             6
# 2019-10-07     1008.00     12   3.016393             6
# 2019-11-07     1009.00     12   2.000000             8
# 2019-12-07     1010.00     12   6.000000             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5   50.000000       A
# 2019-02-07                       2                 0   80.000000     NaN
# 2019-03-07                       2                 4   60.000000     NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv', parse_dates = ['Date'], index_col = 'Class')
df
# Out:
#             Date  Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10    2019-01-07      1001.0        2.0             9                       3
# 10    2019-02-07      1002.0        NaN             8                       2
# 10    2019-03-07         NaN        3.0             8                       2
# 11    2019-06-07         NaN        0.0            10                       1
# 11    2019-07-07      1005.0        4.0             7                       2
# 11    2019-08-07         NaN       10.0             7                       0
# 12    2019-09-07      1007.0        4.0             6                       0
# 12    2019-10-07      1008.0        NaN             6                       2
# 12    2019-11-07      1009.0        2.0             8                       2
# 12    2019-12-07      1010.0        6.0             9                       1
#
#        Mobile Games hrs  Percentage Section
# Class
# 10                    5        50.0       A
# ...

# %%
df.interpolate(method = 'index')
# Out:
#             Date  Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10    2019-01-07      1001.0        2.0             9                       3
# 10    2019-02-07      1002.0        3.0             8                       2
# 10    2019-03-07      1002.0        3.0             8                       2
# 11    2019-06-07      1005.0        0.0            10                       1
# 11    2019-07-07      1005.0        4.0             7                       2
# 11    2019-08-07      1005.0       10.0             7                       0
# 12    2019-09-07      1007.0        4.0             6                       0
# 12    2019-10-07      1008.0        6.0             6                       2
# 12    2019-11-07      1009.0        2.0             8                       2
# 12    2019-12-07      1010.0        6.0             9                       1
#
#        Mobile Games hrs  Percentage Section
# Class
# 10                    5        50.0       A
# ...

# %%
df.interpolate(method = 'nearest')
# Out:
#             Date  Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10    2019-01-07      1001.0        2.0             9                       3
# 10    2019-02-07      1002.0        2.0             8                       2
# 10    2019-03-07      1001.0        3.0             8                       2
# 11    2019-06-07      1005.0        0.0            10                       1
# 11    2019-07-07      1005.0        4.0             7                       2
# 11    2019-08-07      1005.0       10.0             7                       0
# 12    2019-09-07      1007.0        4.0             6                       0
# 12    2019-10-07      1008.0        4.0             6                       2
# 12    2019-11-07      1009.0        2.0             8                       2
# 12    2019-12-07      1010.0        6.0             9                       1
#
#        Mobile Games hrs  Percentage Section
# Class
# 10                    5        50.0       A
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv', parse_dates = ['Date'], index_col = 'Date')
df
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07      1001.0     10        2.0             9
# 2019-02-07      1002.0     10        NaN             8
# 2019-03-07         NaN     10        3.0             8
# 2019-06-07         NaN     11        0.0            10
# 2019-07-07      1005.0     11        4.0             7
# 2019-08-07         NaN     11       10.0             7
# 2019-09-07      1007.0     12        4.0             6
# 2019-10-07      1008.0     12        NaN             6
# 2019-11-07      1009.0     12        2.0             8
# 2019-12-07      1010.0     12        6.0             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5        50.0       A
# 2019-02-07                       2                 0        80.0     NaN
# 2019-03-07                       2                 4        60.0     NaN
# ...

# %%
df.interpolate(method = 'polynomial', order = 1)
# Out:
#             Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07     1001.00     10   2.000000             9
# 2019-02-07     1002.00     10   2.525424             8
# 2019-03-07     1002.56     10   3.000000             8
# 2019-06-07     1004.40     11   0.000000            10
# 2019-07-07     1005.00     11   4.000000             7
# 2019-08-07     1006.00     11  10.000000             7
# 2019-09-07     1007.00     12   4.000000             6
# 2019-10-07     1008.00     12   3.016393             6
# 2019-11-07     1009.00     12   2.000000             8
# 2019-12-07     1010.00     12   6.000000             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5   50.000000       A
# 2019-02-07                       2                 0   80.000000     NaN
# 2019-03-07                       2                 4   60.000000     NaN
# ...

# %%
df.interpolate(method = 'polynomial', order = 2)
# Out:
#              Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07  1001.000000     10   2.000000             9
# 2019-02-07  1002.000000     10   3.138905             8
# 2019-03-07  1002.717152     10   3.000000             8
# 2019-06-07  1004.268975     11   0.000000            10
# 2019-07-07  1005.000000     11   4.000000             7
# 2019-08-07  1005.952316     11  10.000000             7
# 2019-09-07  1007.000000     12   4.000000             6
# 2019-10-07  1008.000000     12   0.864435             6
# 2019-11-07  1009.000000     12   2.000000             8
# 2019-12-07  1010.000000     12   6.000000             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5   50.000000       A
# 2019-02-07                       2                 0   80.000000     NaN
# 2019-03-07                       2                 4   60.000000     NaN
# ...

# %%
df.interpolate(method = 'spline', order = 2)
# Out:
#              Student ID  Class  Study hrs  Sleeping hrs  \
# Date
# 2019-01-07  1001.000000     10   2.000000             9
# 2019-02-07  1002.000000     10   2.948731             8
# 2019-03-07  1002.272184     10   3.000000             8
# 2019-06-07  1004.371369     11   0.000000            10
# 2019-07-07  1005.000000     11   4.000000             7
# 2019-08-07  1006.039818     11  10.000000             7
# 2019-09-07  1007.000000     12   4.000000             6
# 2019-10-07  1008.000000     12   2.522072             6
# 2019-11-07  1009.000000     12   2.000000             8
# 2019-12-07  1010.000000     12   6.000000             9
#
#             Social Media usage hrs  Mobile Games hrs  Percentage Section
# Date
# 2019-01-07                       3                 5   50.000000       A
# 2019-02-07                       2                 0   80.000000     NaN
# 2019-03-07                       2                 4   60.000000     NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results10.csv')
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        NaN             8
# 2   3/7/2019         NaN     10        3.0             8
# 3   6/7/2019         NaN     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019         NaN     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        NaN             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df.interpolate() # axis = 0(column by column)
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.dtypes
# Out:
# Date                       object
# Student ID                float64
# Class                       int64
# Study hrs                 float64
# Sleeping hrs                int64
# Social Media usage hrs      int64
# Mobile Games hrs            int64
# Percentage                float64
# Section                    object
# dtype: object

# %%
df.interpolate(limit = 1)
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019         NaN     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(limit = 2)
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(limit = 1, limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019         NaN     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df.interpolate(limit = 2, limit_direction = 'backward')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df.interpolate(limit = 1, limit_direction = 'both')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(limit_area = 'inside')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df.interpolate(limit_area = 'outside')
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        NaN             8
# 2   3/7/2019         NaN     10        3.0             8
# 3   6/7/2019         NaN     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019         NaN     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        NaN             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        NaN             8
# 2   3/7/2019         NaN     10        3.0             8
# 3   6/7/2019         NaN     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019         NaN     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        NaN             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5         NaN     NaN
# ...

# %%
df.interpolate(inplace = True) # method = linear
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...

# %%
df
# Out:
#         Date  Student ID  Class  Study hrs  Sleeping hrs  \
# 0   1/7/2019      1001.0     10        2.0             9
# 1   2/7/2019      1002.0     10        2.5             8
# 2   3/7/2019      1003.0     10        3.0             8
# 3   6/7/2019      1004.0     11        0.0            10
# 4   7/7/2019      1005.0     11        4.0             7
# 5   8/7/2019      1006.0     11       10.0             7
# 6   9/7/2019      1007.0     12        4.0             6
# 7  10/7/2019      1008.0     12        3.0             6
# 8  11/7/2019      1009.0     12        2.0             8
# 9  12/7/2019      1010.0     12        6.0             9
#
#    Social Media usage hrs  Mobile Games hrs  Percentage Section
# 0                       3                 5        50.0       A
# 1                       2                 0        80.0     NaN
# 2                       2                 4        60.0     NaN
# 3                       1                 5        65.0     NaN
# ...
