# %% [markdown]
# # Handling Missing values in Python

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv')
df
# Out:
#    Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001         10          2             9                       3
# 1        1002         10          6             8                       2
# 2        1003         10          3             8                       2
# 3        1004        NaN          0            10                       1
# 4        1005  no values          4             7                       2
# 5        1006        NaN         10             7                       0
# 6        1007        NaN          4             6                       0
# 7        1008         12         10             6                       2
# 8        1009         12          2             8                       2
# 9        1010         12          6             9                       1
#
#    Mobile Games hrs     Percentage
# 0                 5             50
# 1                 0             80
# 2                 4             60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv', na_values = 'not available')
df
# Out:
#    Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001         10          2             9                       3
# 1        1002         10          6             8                       2
# 2        1003         10          3             8                       2
# 3        1004        NaN          0            10                       1
# 4        1005  no values          4             7                       2
# 5        1006        NaN         10             7                       0
# 6        1007        NaN          4             6                       0
# 7        1008         12         10             6                       2
# 8        1009         12          2             8                       2
# 9        1010         12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv', na_values = ['not available','no values'])
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005    NaN          4             7                       2
# 5        1006    NaN         10             7                       0
# 6        1007    NaN          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5         NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv')
df
# Out:
#    Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001         10          2             9                       3
# 1        1002         10          6             8                       2
# 2        1003         10          3             8                       2
# 3        1004        NaN          0            10                       1
# 4        1005  no values          4             7                       2
# 5        1006        NaN         10             7                       0
# 6        1007        NaN          4             6                       0
# 7        1008         12         10             6                       2
# 8        1009         12          2             8                       2
# 9        1010         12          6             9                       1
#
#    Mobile Games hrs     Percentage
# 0                 5             50
# 1                 0             80
# 2                 4             60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv', na_values = {'Class':'no values'} )
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005    NaN          4             7                       2
# 5        1006    NaN         10             7                       0
# 6        1007    NaN          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs     Percentage
# 0                 5             50
# 1                 0             80
# 2                 4             60
# 3                 5  not available
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv', na_values = {'Class':'no values', 'Percentage':'not available'} )
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005    NaN          4             7                       2
# 5        1006    NaN         10             7                       0
# 6        1007    NaN          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5         NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results8.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005    NaN          4             7                       2
# 5        1006    NaN         10             7                       0
# 6        1007    NaN          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5         NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results8.csv', keep_default_na = False)
df
# Out:
#    Student ID Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001    10          2             9                       3
# 1        1002    10          6             8                       2
# 2        1003    10          3             8                       2
# 3        1004                0            10                       1
# 4        1005  NULL          4             7                       2
# 5        1006  #N/A         10             7                       0
# 6        1007  #N/A          4             6                       0
# 7        1008    12         10             6                       2
# 8        1009    12          2             8                       2
# 9        1010    12          6             9                       1
#
#    Mobile Games hrs Percentage
# 0                 5         50
# 1                 0         80
# 2                 4         60
# 3                 5       NULL
# 4                 0       null
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results8.csv', keep_default_na = True)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   10.0          2             9                       3
# 1        1002   10.0          6             8                       2
# 2        1003   10.0          3             8                       2
# 3        1004    NaN          0            10                       1
# 4        1005    NaN          4             7                       2
# 5        1006    NaN         10             7                       0
# 6        1007    NaN          4             6                       0
# 7        1008   12.0         10             6                       2
# 8        1009   12.0          2             8                       2
# 9        1010   12.0          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5        50.0
# 1                 0        80.0
# 2                 4        60.0
# 3                 5         NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results9.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     14          0            10                       1
# 4        1005     14          4             7                       2
# 5        1006     14         10             7                       0
# 6        1007     14          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          70
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results9.csv', na_filter = False)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     14          0            10                       1
# 4        1005     14          4             7                       2
# 5        1006     14         10             7                       0
# 6        1007     14          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          70
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results9.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     14          0            10                       1
# 4        1005     14          4             7                       2
# 5        1006     14         10             7                       0
# 6        1007     14          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          70
# ...

# %%
df.isnull()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0       False  False      False         False                   False
# 1       False  False      False         False                   False
# 2       False  False      False         False                   False
# 3       False  False      False         False                   False
# 4       False  False      False         False                   False
# 5       False  False      False         False                   False
# 6       False  False      False         False                   False
# 7       False  False      False         False                   False
# 8       False  False      False         False                   False
# 9       False  False      False         False                   False
#
#    Mobile Games hrs  Percentage
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv')
df
# Out:
#    Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001         10          2             9                       3
# 1        1002         10          6             8                       2
# 2        1003         10          3             8                       2
# 3        1004        NaN          0            10                       1
# 4        1005  no values          4             7                       2
# 5        1006        NaN         10             7                       0
# 6        1007        NaN          4             6                       0
# 7        1008         12         10             6                       2
# 8        1009         12          2             8                       2
# 9        1010         12          6             9                       1
#
#    Mobile Games hrs     Percentage
# 0                 5             50
# 1                 0             80
# 2                 4             60
# ...

# %%
df.isnull()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0       False  False      False         False                   False
# 1       False  False      False         False                   False
# 2       False  False      False         False                   False
# 3       False   True      False         False                   False
# 4       False  False      False         False                   False
# 5       False   True      False         False                   False
# 6       False   True      False         False                   False
# 7       False  False      False         False                   False
# 8       False  False      False         False                   False
# 9       False  False      False         False                   False
#
#    Mobile Games hrs  Percentage
# 0             False       False
# 1             False       False
# 2             False       False
# 3             False       False
# ...

# %%
df.isnull().sum()
# Out:
# Student ID                0
# Class                     3
# Study hrs                 0
# Sleeping hrs              0
# Social Media usage hrs    0
# Mobile Games hrs          0
# Percentage                1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results7.csv')
df
# Out:
#    Student ID      Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001         10          2             9                       3
# 1        1002         10          6             8                       2
# 2        1003         10          3             8                       2
# 3        1004        NaN          0            10                       1
# 4        1005  no values          4             7                       2
# 5        1006        NaN         10             7                       0
# 6        1007        NaN          4             6                       0
# 7        1008         12         10             6                       2
# 8        1009         12          2             8                       2
# 9        1010         12          6             9                       1
#
#    Mobile Games hrs     Percentage
# 0                 5             50
# 1                 0             80
# 2                 4             60
# ...

# %%
df.notnull()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        True   True       True          True                    True
# 1        True   True       True          True                    True
# 2        True   True       True          True                    True
# 3        True  False       True          True                    True
# 4        True   True       True          True                    True
# 5        True  False       True          True                    True
# 6        True  False       True          True                    True
# 7        True   True       True          True                    True
# 8        True   True       True          True                    True
# 9        True   True       True          True                    True
#
#    Mobile Games hrs  Percentage
# 0              True        True
# 1              True        True
# 2              True        True
# 3              True        True
# ...

# %%
df.notnull().sum()
# Out:
# Student ID                10
# Class                      7
# Study hrs                 10
# Sleeping hrs              10
# Social Media usage hrs    10
# Mobile Games hrs          10
# Percentage                 9
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 66

# %%
#Series
import numpy as np
sr = pd.Series([1,2,3,np.nan,4,np.nan])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\Fortune.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone          IT Service   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%
# 3   4              NaN         IT Services  23562549    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df.dropna()
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone          IT Service   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%

# %%
df.dropna(axis = 1) # 0-rows(default),1-coloumn
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47689453
# 3   4  23562549
# 4   5   5674893

# %%
df.dropna(how = 'any') # 'any'-default,'all'
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone          IT Service   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%

# %%
df.dropna(axis = 1,how = 'any')
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  23648990
# 2   3  47689453
# 3   4  23562549
# 4   5   5674893

# %%
df.dropna(how = 'all')
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone          IT Service   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%
# 3   4              NaN         IT Services  23562549    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\Fortune.csv')
df
# Out:
#    ID             Name           Companies    Profit Growth
# 0   1          Lamtone          IT Service   5274553    30%
# 1   2        Stripfind  Financial Services  23648990    20%
# 2   3  Canecorporation              Health  47689453     7%
# 3   4              NaN         IT Services  23562549    NaN
# 4   5             Mark                 NaN   5674893    21%

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\Fortune1.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(how = 'all')
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(thresh = 1) # None-default,1-minimum one not null value
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(thresh = 2)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(thresh = 4)
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\Fortune1.csv')
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['ID'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(subset = ['Name'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%

# %%
df.dropna(subset = ['Profit'])
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
# 3  4.0              NaN         IT Services  23562549.0    NaN

# %%
df.dropna(inplace = True) # boolean- True or False
df
# Out:
#     ID             Name           Companies      Profit Growth
# 0  1.0          Lamtone          IT Service   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  23648990.0    20%
# 2  3.0  Canecorporation              Health  47689453.0     7%
