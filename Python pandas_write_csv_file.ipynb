# %% [markdown]
# # How to write CSV file in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Student ID', 'Class', 'Study hrs', 'Sleeping hrs',
#        'Social Media usage hrs', 'Mobile Games hrs', 'Percentage'],
#       dtype='object')

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', nrows = 1)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percentage
# 0                 5          50

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', nrows = 5)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', usecols = [0])
df
# Out:
#    Student ID
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', usecols = [0,1])
df
# Out:
#    Student ID  Class
# 0        1001     10
# 1        1002     10
# 2        1003     10
# 3        1004     11
# 4        1005     11
# 5        1006     11
# 6        1007     12
# 7        1008     12
# 8        1009     12
# 9        1010     12

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', usecols = [0,2,6])
df
# Out:
#    Student ID  Study hrs  Percentage
# 0        1001          2          50
# 1        1002          6          80
# 2        1003          3          60
# 3        1004          0          45
# 4        1005          4          75
# 5        1006         10          96
# 6        1007          4          80
# 7        1008         10          90
# 8        1009          2          60
# 9        1010          6          85

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv')
df
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percentage
# 1                  5          50
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', skiprows = 1)
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', skiprows = 2)
df
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', skiprows = [0])
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', skiprows = [2])
df
# Out:
#             0      1          2             3                       4  \
# 0  Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#                   5           6
# 0  Mobile Games hrs  Percentage
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', skiprows = [1,2,3])
df
# Out:
#       0   1   2   3  4  5   6
# 0  1003  10   3   8  2  4  60
# 1  1004  11   0  10  1  5  45
# 2  1005  11   4   7  2  0  75
# 3  1006  11  10   7  0  0  96
# 4  1007  12   4   6  0  0  80
# 5  1008  12  10   6  2  0  90
# 6  1009  12   2   8  2  4  60
# 7  1010  12   6   9  1  0  85

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', index_col = 'Student ID')
df
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percentage
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', index_col = 'Class')
df
# Out:
#        Student ID  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Class
# 10           1001          2             9                       3
# 10           1002          6             8                       2
# 10           1003          3             8                       2
# 11           1004          0            10                       1
# 11           1005          4             7                       2
# 11           1006         10             7                       0
# 12           1007          4             6                       0
# 12           1008         10             6                       2
# 12           1009          2             8                       2
# 12           1010          6             9                       1
#
#        Mobile Games hrs  Percentage
# Class
# 10                    5          50
# 10                    0          80
# 10                    4          60
# 11                    5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', index_col = 2)
df
# Out:
#            Student ID  Class  Sleeping hrs  Social Media usage hrs  \
# Study hrs
# 2                1001     10             9                       3
# 6                1002     10             8                       2
# 3                1003     10             8                       2
# 0                1004     11            10                       1
# 4                1005     11             7                       2
# 10               1006     11             7                       0
# 4                1007     12             6                       0
# 10               1008     12             6                       2
# 2                1009     12             8                       2
# 6                1010     12             9                       1
#
#            Mobile Games hrs  Percentage
# Study hrs
# 2                         5          50
# 6                         0          80
# 3                         4          60
# 0                         5          45
# ...

# %%
 pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv')
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
 pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv')
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percentage
# 1                  5          50
# ...

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', header = 1)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results3.csv')
# Out:
#     Unnamed: 0   data Unnamed: 2    Unnamed: 3              Unnamed: 4  \
# 0            0      1          2             3                       4
# 1   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 2         1001     10          2             9                       3
# 3         1002     10          6             8                       2
# 4         1003     10          3             8                       2
# 5         1004     11          0            10                       1
# 6         1005     11          4             7                       2
# 7         1006     11         10             7                       0
# 8         1007     12          4             6                       0
# 9         1008     12         10             6                       2
# 10        1009     12          2             8                       2
# 11        1010     12          6             9                       1
#
#           Unnamed: 5  Unnamed: 6
# ...

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results2.csv', header = 2)
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv')
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', header = None)
# Out:
#       0   1   2   3  4  5   6
# 0  1001  10   2   9  3  5  50
# 1  1002  10   6   8  2  0  80
# 2  1003  10   3   8  2  4  60
# 3  1004  11   0  10  1  5  45
# 4  1005  11   4   7  2  0  75
# 5  1006  11  10   7  0  0  96
# 6  1007  12   4   6  0  0  80
# 7  1008  12  10   6  2  0  90
# 8  1009  12   2   8  2  4  60
# 9  1010  12   6   9  1  0  85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', header = None, prefix = 'Columns')
# Out:
#    Columns0  Columns1  Columns2  Columns3  Columns4  Columns5  Columns6
# 0      1001        10         2         9         3         5        50
# 1      1002        10         6         8         2         0        80
# 2      1003        10         3         8         2         4        60
# 3      1004        11         0        10         1         5        45
# 4      1005        11         4         7         2         0        75
# 5      1006        11        10         7         0         0        96
# 6      1007        12         4         6         0         0        80
# 7      1008        12        10         6         2         0        90
# 8      1009        12         2         8         2         4        60
# 9      1010        12         6         9         1         0        85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', header = None, prefix = 'Col')
# Out:
#    Col0  Col1  Col2  Col3  Col4  Col5  Col6
# 0  1001    10     2     9     3     5    50
# 1  1002    10     6     8     2     0    80
# 2  1003    10     3     8     2     4    60
# 3  1004    11     0    10     1     5    45
# 4  1005    11     4     7     2     0    75
# 5  1006    11    10     7     0     0    96
# 6  1007    12     4     6     0     0    80
# 7  1008    12    10     6     2     0    90
# 8  1009    12     2     8     2     4    60
# 9  1010    12     6     9     1     0    85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', header = None, prefix = 'Data')
# Out:
#    Data0  Data1  Data2  Data3  Data4  Data5  Data6
# 0   1001     10      2      9      3      5     50
# 1   1002     10      6      8      2      0     80
# 2   1003     10      3      8      2      4     60
# 3   1004     11      0     10      1      5     45
# 4   1005     11      4      7      2      0     75
# 5   1006     11     10      7      0      0     96
# 6   1007     12      4      6      0      0     80
# 7   1008     12     10      6      2      0     90
# 8   1009     12      2      8      2      4     60
# 9   1010     12      6      9      1      0     85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', names = ['A','B','C','D','E','F','G'])
# Out:
#       A   B   C   D  E  F   G
# 0  1001  10   2   9  3  5  50
# 1  1002  10   6   8  2  0  80
# 2  1003  10   3   8  2  4  60
# 3  1004  11   0  10  1  5  45
# 4  1005  11   4   7  2  0  75
# 5  1006  11  10   7  0  0  96
# 6  1007  12   4   6  0  0  80
# 7  1008  12  10   6  2  0  90
# 8  1009  12   2   8  2  4  60
# 9  1010  12   6   9  1  0  85

# %%
pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results4.csv', names = ['Student Id','Class','Study hrs','Sleeping hrs','Social media usage hrs','Mobile games hrs','Percentage'])
# Out:
#    Student Id  Class  Study hrs  Sleeping hrs  Social media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df.head()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75

# %%
df.head(1)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
#
#    Mobile Games hrs  Percentage
# 0                 5          50

# %%
df.head(8)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# 4                 0          75
# 5                 0          96
# 6                 0          80
# 7                 0          90

# %%
df.tail()
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 5                 0          96
# 6                 0          80
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
df.tail(2)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 8                 4          60
# 9                 0          85

# %%
df.tail(7)
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 3                 5          45
# 4                 0          75
# 5                 0          96
# 6                 0          80
# 7                 0          90
# 8                 4          60
# 9                 0          85

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv')
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', dtype = {'Student ID':'float64'})
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10          2             9                       3
# 1      1002.0     10          6             8                       2
# 2      1003.0     10          3             8                       2
# 3      1004.0     11          0            10                       1
# 4      1005.0     11          4             7                       2
# 5      1006.0     11         10             7                       0
# 6      1007.0     12          4             6                       0
# 7      1008.0     12         10             6                       2
# 8      1009.0     12          2             8                       2
# 9      1010.0     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results.csv', dtype = {'Student ID':'float64', 'Study hrs':'float64'})
df
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0      1001.0     10        2.0             9                       3
# 1      1002.0     10        6.0             8                       2
# 2      1003.0     10        3.0             8                       2
# 3      1004.0     11        0.0            10                       1
# 4      1005.0     11        4.0             7                       2
# 5      1006.0     11       10.0             7                       0
# 6      1007.0     12        4.0             6                       0
# 7      1008.0     12       10.0             6                       2
# 8      1009.0     12        2.0             8                       2
# 9      1010.0     12        6.0             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results5.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001  Yes     10          2             9                       3
# 1        1002  Yes     10          6             8                       2
# 2        1003  Yes     10          3             8                       2
# 3        1004  Yes     11          0            10                       1
# 4        1005  Yes     11          4             7                       2
# 5        1006  Yes     11         10             7                       0
# 6        1007  Yes     12          4             6                       0
# 7        1008  Yes     12         10             6                       2
# 8        1009  Yes     12          2             8                       2
# 9        1010  Yes     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results5.csv', true_values = ['Yes'])
df
# Out:
#    Student ID  Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001  True     10          2             9                       3
# 1        1002  True     10          6             8                       2
# 2        1003  True     10          3             8                       2
# 3        1004  True     11          0            10                       1
# 4        1005  True     11          4             7                       2
# 5        1006  True     11         10             7                       0
# 6        1007  True     12          4             6                       0
# 7        1008  True     12         10             6                       2
# 8        1009  True     12          2             8                       2
# 9        1010  True     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results6.csv')
df
# Out:
#    Student ID Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001  Yes     10          2             9                       3
# 1        1002   No     10          6             8                       2
# 2        1003   No     10          3             8                       2
# 3        1004  Yes     11          0            10                       1
# 4        1005  Yes     11          4             7                       2
# 5        1006   No     11         10             7                       0
# 6        1007   No     12          4             6                       0
# 7        1008  Yes     12         10             6                       2
# 8        1009  Yes     12          2             8                       2
# 9        1010  Yes     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# 2                 4          60
# ...

# %%
df = pd.read_csv('C:\\Users\\Saurabh\\OneDrive\\Documents\\student_results6.csv', true_values = ['Yes'], false_values = ['No'])
df
# Out:
#    Student ID   Date  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001   True     10          2             9                       3
# 1        1002  False     10          6             8                       2
# 2        1003  False     10          3             8                       2
# 3        1004   True     11          0            10                       1
# 4        1005   True     11          4             7                       2
# 5        1006  False     11         10             7                       0
# 6        1007  False     12          4             6                       0
# 7        1008   True     12         10             6                       2
# 8        1009   True     12          2             8                       2
# 9        1010   True     12          6             9                       1
#
#    Mobile Games hrs  Percentage
# 0                 5          50
# 1                 0          80
# ...
